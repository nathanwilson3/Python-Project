# %% [markdown]
# #### Extracting data from web pages with BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# Target webpage URL (replace with your desired URL)
url = 'https://www.fangraphs.com/leaders/major-league'

# Fetch the webpage content
try:
    response = requests.get(url)
    response.raise_for_status() # Check for HTTP errors
except requests.exceptions.RequestException as e:
    print(f"Error fetching the webpage: {e}")
else:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Now, 'soup' holds a structured representation of the webpage, ready for our exploration

# %%
headings = soup.find_all('h1')

for heading in headings:
    print(heading.text.strip()) # Strip removes any extra whitespace
# Out:
# Major League Leaders

# %%
links = soup.find_all('a')

for link in links:
    href = link.get('href')
    if href:  # Make sure the link has a valid 'href' attribute
        print(href)
# Out:
# /
# https://www.fangraphs.com/blogs/wp-login.php?redirect_to=null
# https://plus.fangraphs.com/product/fangraphs-membership/
# https://plus.fangraphs.com/shop/
# https://plus.fangraphs.com/product/fangraphs-gift-membership/
# https://plus.fangraphs.com/product/fangraphs-donation/
# /fantasy-tools/player-rater
# /fantasy-tools/auction-calculator
# //ottoneu.fangraphs.com/
# //ottoneu.fangraphs.com/
# //ottoneu.fangraphs.com/support
# //www.fangraphs.com/fantasy/category/ottoneu/
# /blog-roll
# https://www.fangraphs.com/blogs/
# /blog-roll?category=Effectively+Wild
# https://www.fangraphs.com/prospects/
# /rotographs
# https://www.fangraphs.com/fantasy/category/podcast/
# https://www.fangraphs.com/fantasy/category/field-of-streams/
# https://fantasy.fangraphs.com/category/beat-the-shift/
# https://www.fangraphs.com/community/
# https://www.fangraphs.com/tht/
# https://www.fangraphs.com/not/
# https://www.fangraphs.com/techgraphs/
# https://www.fangraphs.com/plus/
# https://www.fangraphs.com/tht/tht-live/
# https://www.fangraphs.com/tht/category/tht-dispatch/
# https://www.fangraphs.com/tht/category/tht-fantasy/
# htttps://www.fangraphs.com/tht/category/shysterball/
# https://www.fangraphs.com/blogs/category/podcast/
# https://blogs.fangraphs.com/category/chin-music/
# https://www.fangraphs.com/blogs/category/ump-the-untitled-mcdongenhagen-project/
# https://www.fangraphs.com/tht/stealing-home/
# https://www.fangraphs.com/tht/doing-it-for-bartolo/
# https://www.fangraphs.com/fantasy/category/ottographs-podcast/
# /projections?pos=all&stats=bat&type=zips
# /projections?pos=all&stats=bat&type=zipsdc
# /projections?pos=all&stats=bat&type=steamer
# /projections?pos=all&stats=bat&type=fangraphsdc
# /projections?pos=all&stats=bat&type=atc
# /projections?pos=all&stats=bat&type=thebat
# /projections?pos=all&stats=bat&type=thebatx
# /projections?pos=all&stats=bat&type=oopsy
# /projections?pos=all&stats=bat&type=steamer600
# /projections?pos=all&stats=bat&type=steamer600u
# /projections?pos=all&stats=bat&type=rzips
# /projections?pos=all&stats=bat&type=uzips
# /projections?pos=all&stats=bat&type=rzipsdc
# /projections?pos=all&stats=bat&type=steamerr
# /projections?pos=all&stats=bat&type=steameru
# /projections?pos=all&stats=bat&type=rfangraphsdc
# /projections?pos=all&stats=bat&type=ratcdc
# /projections?pos=all&stats=bat&type=rthebat
# /projections?pos=all&stats=bat&type=rthebatx
# /projections?pos=all&stats=bat&type=roopsydc
# /projections?pos=all&stats=bat&type=zipsp1
# /projections?pos=all&stats=bat&type=zipsp2
# /projections?pos=all&stats=bat&type=onpaceegp
# /projections?pos=all&stats=bat&type=onpacegpp
# /projections/cy-young
# /fantasy-tools/auction-calculator
# /scores
# /leaders/major-league?pos=all&stats=pit&lg=all&qual=0&type=8&season=
# //www.fangraphs.com/roster-resource/depth-charts/athletics
# //www.fangraphs.com/roster-resource/depth-charts/mariners
# //www.fangraphs.com/roster-resource/depth-charts/rangers
# //www.fangraphs.com/roster-resource/depth-charts/braves
# //www.fangraphs.com/roster-resource/depth-charts/marlins
# //www.fangraphs.com/roster-resource/depth-charts/mets
# //www.fangraphs.com/roster-resource/depth-charts/nationals
# //www.fangraphs.com/roster-resource/depth-charts/phillies
# //www.fangraphs.com/roster-resource/depth-charts/brewers
# //www.fangraphs.com/roster-resource/depth-charts/cardinals
# //www.fangraphs.com/roster-resource/depth-charts/cubs
# //www.fangraphs.com/roster-resource/depth-charts/pirates
# //www.fangraphs.com/roster-resource/depth-charts/reds
# //www.fangraphs.com/roster-resource/depth-charts/diamondbacks
# //www.fangraphs.com/roster-resource/depth-charts/dodgers
# //www.fangraphs.com/roster-resource/depth-charts/giants
# //www.fangraphs.com/roster-resource/depth-charts/padres
# //www.fangraphs.com/roster-resource/depth-charts/rockies
# //www.fangraphs.com/roster-resource/free-agent-tracker
# //www.fangraphs.com/roster-resource/offseason-tracker
# //www.fangraphs.com/roster-resource/opening-day-tracker
# /roster-resource/closer-depth-chart
# /roster-resource/injury-report
# /roster-resource/payroll/padres
# /roster-resource/transaction-tracker
# /roster-resource/schedule-grid
# /roster-resource/probables-grid
# /roster-resource/lineup-tracker/padres
# /roster-resource/minor-league-power-rankings
# //www.fangraphs.com/prospects
# /prospects/the-board
# //www.fangraphs.com/prospects/the-board-scouting-and-stats
# //blogs.fangraphs.com/how-to-use-the-board-a-tutorial-2022/
# /prospects/farm-system-rankings
# https://blogs.fangraphs.com/2025-top-100-prospects/
# //www.fangraphs.com/library/
# //www.fangraphs.com/library/offense/woba/
# //www.fangraphs.com/library/offense/wrc/
# //www.fangraphs.com/library/offense/iso/
# //www.fangraphs.com/library/offense/rate-stats/
# //www.fangraphs.com/library/offense/
# //www.fangraphs.com/library/pitching/fip/
# //www.fangraphs.com/library/pitching/xfip/
# //www.fangraphs.com/library/pitching/babip/
# //www.fangraphs.com/library/pitching/rate-stats/
# //www.fangraphs.com/library/pitching/
# //www.fangraphs.com/blogs/the-fangraphs-uzr-primer/
# //www.fangraphs.com/library/defense/drs/
# //www.fangraphs.com/library/defense/fsr/
# //www.fangraphs.com/library/defense/tz-tzl/
# //www.fangraphs.com/library/defense/
# //www.fangraphs.com/library/misc/war/
# //www.fangraphs.com/blogs/ultimate-base-running-primer/
# //www.fangraphs.com/library/misc/wpa/
# //www.fangraphs.com/library/misc/li/
# //www.fangraphs.com/library/misc/clutch/
# /tools/guts?type=cn
# /tools/guts?type=pf
# /tools/guts?type=pfh
# https://www.fangraphs.com/blogs/wp-login.php?redirect_to=null
# https://www.fangraphs.com/leaders/splits-leaderboards
# /leaders/war
# https://www.fangraphs.com/leaders/spring-training/
# https://www.fangraphs.com/leaders/splits-leaderboards
# /leaders/war
# https://www.fangraphs.com/leaders/minor-league/
# https://www.fangraphs.com/leaders/spring-training/
# /leaders/major-league?month=0&pos=all&stats=bat&type=8
# /leaders/major-league?month=0&pos=all&stats=pit&type=8
# /leaders/major-league?pos=all&stats=fld&type=1&startdate=&enddate=&month=0&qual=y
# /leaders/major-league?team=0
# /leaders/major-league?team=9
# /players/cal-raleigh/21534/stats?position=C
# /leaders/major-league?team=11
# /players/bobby-witt-jr/25764/stats?position=SS
# /leaders/major-league?team=7
# /players/shohei-ohtani/19755/stats?position=DH
# /leaders/major-league?team=22
# /players/geraldo-perdomo/22799/stats?position=SS
# /leaders/major-league?team=15
# /players/trea-turner/16252/stats?position=SS
# /leaders/major-league?team=26
# /players/corbin-carroll/25878/stats?position=OF
# /leaders/major-league?team=15
# /players/jose-ramirez/13510/stats?position=3B
# /leaders/major-league?team=5
# /players/francisco-lindor/12916/stats?position=SS
# /leaders/major-league?team=25
# /players/fernando-tatis-jr/19709/stats?position=SS%2FOF
# /leaders/major-league?team=29
# /players/juan-soto/20123/stats?position=OF
# /leaders/major-league?team=25
# /players/julio-rodriguez/23697/stats?position=OF
# /leaders/major-league?team=11
# /players/jeremy-pena/21636/stats?position=SS
# /leaders/major-league?team=21
# /players/maikel-garcia/22715/stats?position=3B
# /leaders/major-league?team=7
# /players/pete-crow-armstrong/27769/stats?position=OF
# /leaders/major-league?team=17
# /players/george-springer/12856/stats?position=OF
# /leaders/major-league?team=14
# /players/byron-buxton/14161/stats?position=OF
# /leaders/major-league?team=8
# /players/kyle-schwarber/16478/stats?position=DH%2FOF
# /leaders/major-league?team=26
# /players/cody-bellinger/15998/stats?position=1B%2FOF
# /leaders/major-league?team=9
# /players/nico-hoerner/21479/stats?position=2B%2FSS
# /leaders/major-league?team=17
# /players/gunnar-henderson/26289/stats?position=SS
# /leaders/major-league?team=2
# /players/matt-olson/14344/stats?position=1B
# /leaders/major-league?team=16
# /players/alejandro-kirk/22581/stats?position=C
# /leaders/major-league?team=14
# /players/ketel-marte/13613/stats?position=2B
# /leaders/major-league?team=15
# /players/junior-caminero/28163/stats?position=3B
# /leaders/major-league?team=12
# /players/kyle-tucker/18345/stats?position=OF
# /leaders/major-league?team=17
# /players/brice-turang/22186/stats?position=2B
# /leaders/major-league?team=23
# /players/jazz-chisholm-jr/20454/stats?position=2B%2FOF
# /leaders/major-league?team=9
# /players/elly-de-la-cruz/26668/stats?position=SS
# /leaders/major-league?team=18
# /players/wyatt-langford/33333/stats?position=OF
# /leaders/major-league?team=13
# https://twitter.com/@fangraphs
# https://blogs.fangraphs.com/contact/
# https://blogs.fangraphs.com/advertise/
# https://www.fangraphs.com/about/terms-of-service
# https://www.fangraphs.com/about/privacy-policy
# https://www.sportsinfosolutions.com/
# https://www.mlb.com
# http://www.tangotiger.com
# https://www.retrosheet.org

# %% [markdown]
# ### Real Life Example: Sports Data Analyst

# %%
import requests
from bs4 import BeautifulSoup

# Target a Sports Data webpage URL (replace with your desired URL)
url = 'https://www.fangraphs.com/leaders/major-league'

# Fetch the webpage content
try:
    response = requests.get(url)
    response.raise_for_status()  # Check for HTTP errors
except requests.exceptions.RequestException as e:
    print(f"Error fetching the webpage: {e}")
else:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Now, 'soup' holds the structured represntation of the webpage, ready for our exploration!

    sports = soup.find_all('div', class_='leaders-major_leaders-major_table_hcmbm')

    for sports in sports:
        # Extract the player name:
        player = sport.find('td', class_='align-left fixed').text.strip()
        # Extract the number of games played by the player:
        games_played = sport.find('td', class_='align-right').text.strip()
        print(f"Player: {player}, Games Played: {games_played}\n")
